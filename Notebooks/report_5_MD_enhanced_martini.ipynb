# %% [markdown]
# <a href="https://colab.research.google.com/github/carlocamilloni/Structural-Bioinformatics/blob/main/Notebooks/report_5_MD_enhanced_martini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REPORT: Enhanced Sampling and Simplified Models in MD

# %% [markdown]
# ## Preliminary Operations

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive

# %%
# set the path to your local task folder
local_path='/content/drive/MyDrive/Structural_Bioinformatics/Task5'
# %cd {local_path}

# %% [markdown]
# your name

# %%
from datetime import date

today = date.today()
print(today)

# %% [markdown]
# ##GROUP 1: Metadynamics on Alanine Dipeptide

# %%
# %cd {local_path}
# %cd MTD

# %% [markdown]
# **Figure 1**: analyze the standard 10 ns long MD simulation: report about the sampling of the backbone dihedral angles phi and psi.
#
# * How many states are visible as a function of phi? What is their relative free energy? And their population?
# * How many states are visible as a function of psi? What is their relative free energy? And their population?

# %% [markdown]
# **Figure 2**: run a longer MD simulation (you need to modify the number of steps in the file run.mdp) and analyze the new simulation again using the `plumed driver` as shown in the instruction.
#
# * How many states are visible as a function of phi? What is their relative free energy? And their population?
# * How many states are visible as a function of psi? What is their relative free energy? And their population?
#
# What is the difference with the shorter simulation?

# %% [markdown]
# **Figure 3**: analyze the time evolution of the free energy estimates as a function of phi and psi. How many states are visited? What is their population? (be careful, when using metadynamics the populations must be estimated from the free energy)

# %% [markdown]
# **Figure 4**: run a longer metadynamics simulation and analyze again the time evolution of the free energy estimates as a function of phi and psi. How many states are visited? What is their population? (be careful, when using metadynamics the populations must be estimated from the free energy)
#
# What is the difference with the shorter simulation?

# %% [markdown]
# **Figure 5**: Describe the 2D Free Energy Surface resulting from the Metadynamics simulation and calculate the population of the beta, alpha and left-alpha regions. What is the difference in analysising 1D and 2D free energies?

# %% [markdown]
# ##GROUP 2: Martini simulation of a DPPC membrane

# %%
# %cd {local_path}
# %cd martini

# %% [markdown]
# Make a figure showing the system at different stage of the simulation:
#
#
# 1.   The initial random disposition
# 2.   The configuration after the first md
# 3.   The configuration after the second md

# %%
#Figure

# %%
#compare the area per lipid in the two simulations:
import matplotlib.pyplot as plt
import csv
import numpy as np

time_md=[]
area_md=[]

time_eq=[]
area_eq=[]

with open('box-x-md.xvg', 'r') as file:
    for row in file:
        if row.split()[0] == '#':
          continue
        if row.split()[0] == '@':
          continue
        if row.split()[0] == '@TYPE':
          continue
        time_md.append(float(row.split()[0]))
        area_md.append(float(row.split()[1]))


file.close()

with open('box-x-eq.xvg', 'r') as file:
    for row in file:
        if row.split()[0] == '#':
          continue
        if row.split()[0] == '@':
          continue
        if row.split()[0] == '@TYPE':
          continue
        time_eq.append(float(row.split()[0]))
        area_eq.append(float(row.split()[1]))


file.close()

# Calculate area per lipid using numpy for element-wise operations
area_per_lipid_md = np.array(area_md)**2 / 64
area_per_lipid_eq = np.array(area_eq)**2 / 64

# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(1,2)
figure.set_size_inches(18.5, 10.5)

axis[0].plot(time_md,area_per_lipid_md,'.')
axis[0].set_ylabel("area per lipid (nm^2)")
axis[0].set_xlabel("Time (ps)")

axis[1].plot(time_eq,area_per_lipid_eq,'.')
axis[1].set_ylabel("area per lipid (nm^2)")
axis[1].set_xlabel("Time (ps)")

plt.show()

# %% [markdown]
# **Figure 2**: what is the different behavior showed in the two panels?

# %% [markdown]
# Have a look at the self-assembly process: can you recognize intermediate states, such as micelles, and do you see metastable structures such as a water pore (water spanning the membrane interior) and/or a lipid bridge (lipid tail(s) spanning the water layer)?

# %%
#Figure to show some special configuration you found looking at the self-assembly process

# %% [markdown]
# **Figure 3:** describe the figure you added
