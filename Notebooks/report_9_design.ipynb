# %% [markdown]
# <a href="https://colab.research.google.com/github/carlocamilloni/Structural-Bioinformatics/blob/main/Notebooks/report_9_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Protein Design

# %% [markdown]
# your name

# %%
from datetime import date

today = date.today()
print(today)

# %% [markdown]
# In this TASK both groups can try to generate three designs as follows: 1) a design of a novel oligomeric protein (this is from the instruction)
# 2) a design of a protein binder against
# 3) a scaffolding of an active site into a new protein

# %% [markdown]
# ## Design a novel protein structure

# %% [markdown]
# **Figure 1**: Schematize the procedure you followed and show the final result

# %% [markdown]
# **Figure 2**: use https://search.foldseek.com/search to search for a similar structure on the public repositories. Is your protein new? What is the closest protein in terms of sequence similarity?

# %% [markdown]
# ## Design a protein binder

# %% [markdown]
# **Group 1:** Design a binder targeting the NS3/4A HCV protease. To do that you need to identify a target protein and chain from the PDB and then follow the instructions provided and what you learned from the first exercise.

# %% [markdown]
# **Group 2:** Design a binder targeting the Dengue virus RNA helicase. To do that you need to identify a target protein and chain from the PDB and then follow the instructions provided and what you learned from the first exercise.

# %% [markdown]
# **Figure 1**: Schematize the procedure you followed and show the final result

# %% [markdown]
# **Figure 2**: use https://search.foldseek.com/search to search for a similar structure on the public repositories. Is your protein new? What is the closest protein in terms of sequence similarity?

# %% [markdown]
# ## Design a protein scaffold to incorporate an existing protein site

# %% [markdown]
# **Group 1**: scaffold into a designed de-novo protein the active site of Ketosteroid Isomerase from Pseudomonas putida Biotype B. You can use the PDB 1C7H, or another you identify. There is a Tyr/Asp catalytic dyad.

# %% [markdown]
# **Group 2**: scaffold into a designed de-novo protein the active site of ROTIDINE 5'-MONOPHOSPHATE DECARBOXYLASE FROM BACILLUS SUBTILIS. You can use the PDB 1DBT, or another you identify. There is a Lys/Asp catalytic dyad.

# %% [markdown]
# **Figure 1**: Schematize the procedure you followed and show the final result

# %% [markdown]
# **Figure 2**: use https://search.foldseek.com/search to search for a similar structure on the public repositories. Is your protein new? What is the closest protein in terms of sequence similarity?
